# %%
import numpy as np
from numpy import pi,sin
print(np.pi)
# Out:
# 3.141592653589793

# %%
print(np.sin(pi))
# Out:
# 1.2246467991473532e-16

# %%
print(np.sin(pi/2))
# Out:
# 1.0

# %%
print(np.cos(pi))
# Out:
# -1.0

# %%
print(np.tan(pi/2))
# Out:
# 1.633123935319537e+16

# %%
import numpy as np
from numpy import pi,sin
x = np.linspace(0,2*pi,10)
y = np.sin(x)
print(y)
# Out:
# [ 0.00000000e+00  6.42787610e-01  9.84807753e-01  8.66025404e-01
#   3.42020143e-01 -3.42020143e-01 -8.66025404e-01 -9.84807753e-01
#  -6.42787610e-01 -2.44929360e-16]

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,1,100)
y = np.sin(x)
plt.plot(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-4*np.pi,4*np.pi,100)
plt.plot(x, np.sin(x)/x)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,4*np.pi,500)
plt.plot(x, np.sin(x)**4 + np.cos(x)**2)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %%
import numpy as np
from numpy import  cos
import matplotlib.pyplot as plt
x = np.linspace(0,1,1000)
plt.plot(x, np.cos(1/(x-x*2))**2)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# C:\Users\vkgup\AppData\Local\Temp\ipykernel_13616\3660477202.py:5: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(x, np.cos(1/(x-x*2))**2)
# C:\Users\vkgup\AppData\Local\Temp\ipykernel_13616\3660477202.py:5: RuntimeWarning: invalid value encountered in cos
#   plt.plot(x, np.cos(1/(x-x*2))**2)
# Text(0, 0.5, 'y-axis')
